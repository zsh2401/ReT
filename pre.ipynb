# %%
import json

import tqdm
# !pip install torch torchvision torchaudio librosa numpy matplotlib tqdm transformers mido
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: torch in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (0.20.1)
# Requirement already satisfied: torchaudio in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: librosa in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (0.10.2.post1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (2.0.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: transformers in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (4.46.3)
# Requirement already satisfied: mido in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (1.3.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/retro/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)

# %%
import torch.utils.data
import os
from mido import MidiFile


def find_all_mid_files(directory):
    mid_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.mid'):  # 检查是否为 .mid 文件
                mid_files.append(os.path.join(root, file))
    return mid_files


def midi_to_sequence(midi_path):
    midi = MidiFile(midi_path)
    sequence = []
    for track in midi.tracks:
        for msg in track:
            if msg.is_meta:
                continue
            if msg.type == 'note_on' and msg.velocity > 0:
                sequence.append(f"Note_On_{msg.note}")
            elif msg.type == 'note_off' or (msg.type == 'note_on' and msg.velocity == 0):
                sequence.append(f"Note_Off_{msg.note}")
            elif msg.type == 'control_change':
                sequence.append(f"Control_{msg.control}_{msg.value}")
            elif msg.type == 'program_change':
                sequence.append(f"Program_{msg.program}")
            elif msg.type == 'time_signature':
                sequence.append(f"Time_Signature_{msg.numerator}/{msg.denominator}")
            elif msg.type == 'set_tempo':
                sequence.append(f"Tempo_{msg.tempo}")
            else:
                raise Exception(f"Unknown message type: {msg.type}")
    return sequence


midi_files = find_all_mid_files("./dataset/nesmdb/nesmdb_midi")
_raw_sequence = dict()


def seq_of(file):
    if len(_raw_sequence) == 0:
        for _file in tqdm.tqdm(midi_files, desc="Building sequences"):
            _raw_sequence[_file] = midi_to_sequence(_file)
    return _raw_sequence[file]


seq_of(midi_files[0])
# Out:
# Building sequences: 100%|██████████| 5278/5278 [01:17<00:00, 68.45it/s]
# ['Program_80',
#  'Control_12_2',
#  'Note_On_69',
#  'Control_11_10',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_80',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_80',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_75',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_75',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_71',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_71',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_77',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_77',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_80',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_80',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_74',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_75',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_75',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_78',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_78',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_87',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_87',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_80',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_80',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_88',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_88',
#  'Note_On_89',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_89',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_86',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_86',
#  'Note_On_82',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_82',
#  'Note_On_89',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_89',
#  'Note_On_88',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_88',
#  'Note_On_84',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_84',
#  'Note_On_83',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_83',
#  'Note_On_80',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_80',
#  'Note_On_81',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_72',
#  'Note_On_76',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_69',
#  'Note_On_68',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_68',
#  'Note_On_67',
#  'Control_11_12',
#  'Control_11_10',
#  'Note_Off_67',
#  'Note_On_76',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_76',
#  'Note_On_77',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_77',
#  'Note_On_78',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_78',
#  'Note_On_79',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_79',
#  'Note_On_80',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_80',
#  'Note_On_80',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_80',
#  'Note_On_79',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_78',
#  'Note_On_77',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_77',
#  'Note_On_76',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_76',
#  'Note_On_76',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_76',
#  'Note_On_77',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_77',
#  'Note_On_78',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_78',
#  'Note_On_79',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_79',
#  'Note_On_80',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_80',
#  'Note_On_80',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_80',
#  'Note_On_79',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_78',
#  'Note_On_77',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_77',
#  'Note_On_76',
#  'Control_11_14',
#  'Control_11_13',
#  'Control_11_12',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_10',
#  'Note_Off_69',
#  'Program_81',
#  'Control_12_2',
#  'Note_On_69',
#  'Control_11_6',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_71',
#  'Note_On_76',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_72',
#  'Note_On_79',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_79',
#  'Note_On_78',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_78',
#  'Note_On_74',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_74',
#  'Note_On_77',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_77',
#  'Note_On_71',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_71',
#  'Note_On_71',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_71',
#  'Note_On_74',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_76',
#  'Note_On_77',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_77',
#  'Note_On_84',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_84',
#  'Note_On_83',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_83',
#  'Note_On_80',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_80',
#  'Note_On_81',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_81',
#  'Note_On_76',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_72',
#  'Note_On_72',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_72',
#  'Note_On_74',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_74',
#  'Note_On_76',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_81',
#  'Note_On_75',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_75',
#  'Note_On_76',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_76',
#  'Note_On_78',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_78',
#  'Note_On_83',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_83',
#  'Note_On_83',
#  'Control_11_8',
#  'Control_11_6',
#  'Note_Off_83',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_74',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_74',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_68',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_68',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_68',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_68',
#  'Note_On_65',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_65',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_62',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_62',
#  'Note_On_60',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_60',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_65',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_65',
#  'Note_On_62',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_62',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_68',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_68',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_74',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_74',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_68',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_68',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_73',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_73',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_73',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_73',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_66',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_66',
#  'Note_On_63',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_63',
#  'Note_On_60',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_60',
#  'Note_On_64',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_64',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_75',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_75',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_69',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_69',
#  'Note_On_71',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_71',
#  'Note_On_68',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_68',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_81',
#  'Note_On_84',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_84',
#  'Note_On_84',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_84',
#  'Note_On_81',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_81',
#  'Note_On_81',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_81',
#  'Note_On_80',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_80',
#  'Note_On_80',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_80',
#  'Note_On_74',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_74',
#  'Note_On_74',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_74',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_72',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_72',
#  'Note_On_76',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_76',
#  'Note_On_81',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_81',
#  'Note_On_84',
#  'Control_11_10',
#  'Control_11_8',
#  'Note_Off_84',
#  'Note_On_84',
#  'Control_11_10',
#  ...]

# %%
def build_vocab():
    vocab = set()
    vocab.add("<PAD>")
    vocab.add("<BOS>")
    vocab.add("<EOS>")
    for file in tqdm.tqdm(midi_files, desc="Building vocabulary"):
        for note in seq_of(file):
            vocab.add(note)
    import json
    V_dict = {token: idx for idx, token in enumerate(sorted(vocab))}
    with open("vocab.json", "w") as f:
        json.dump(V_dict, f)


def load_vocab():
    with open("vocab.json", "r") as f:
        return json.load(f)


build_vocab()
V_dict = load_vocab()
V_dict["<PAD>"]
# Out:
# Building vocabulary: 100%|██████████| 5278/5278 [00:01<00:00, 3183.14it/s]
# 1

# %%
def cal_avg_len():
    sum = 0
    for file in midi_files:
        sum += len(seq_of(file))
    return int(sum / len(midi_files))


# S_len = cal_avg_len()
S_len = 2048
print(f"每个词条的平均长度是：{cal_avg_len()}，取S_len为{S_len}", )
# Out:
# 每个词条的平均长度是：2947，取S_len为2048

# %%
def to_std_seq_vector(seq, s_len=S_len):
    arr = [V_dict[a] for a in seq]
    arr.insert(0, V_dict["<BOS>"])
    arr = arr[:s_len - 1]
    if len(arr) < s_len:
        arr.append(V_dict["<EOS>"])
    while len(arr) < s_len:
        arr.append(V_dict["<PAD>"])
    return arr


class NesMusicDataset(torch.utils.data.Dataset):
    def __init__(self):
        super(NesMusicDataset, self).__init__()

    def __len__(self):
        return len(midi_files)

    def __getitem__(self, idx):
        seq = seq_of(midi_files[idx])
        seq = to_std_seq_vector(seq)
        input_seq = seq[:-1]
        target_seq = seq[1:]
        return torch.tensor(input_seq), torch.tensor(target_seq)


dataset = NesMusicDataset()
len(to_std_seq_vector(["<PAD>"]))
# len(dataset[0][])
# std_seq_of()
# dataset[0][:10]
# V_dict["<BOS>"]
# Out:
# 2048

# %%
import torch.nn as nn


class MusicTransformer(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_heads, num_layers, max_len, pad_token):
        super(MusicTransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=pad_token)
        self.positional_encoding = nn.Parameter(torch.zeros(max_len, embed_dim))
        self.transformer = nn.Transformer(
            d_model=embed_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            num_decoder_layers=num_layers,
            dim_feedforward=2048,
        )
        self.fc_out = nn.Linear(embed_dim, vocab_size)
        self.pad_token = pad_token

    def forward(self, src, tgt, src_mask=None, tgt_mask=None, src_padding_mask=None, tgt_padding_mask=None):
        # Embedding + Positional Encoding
        src_emb = self.embedding(src) + self.positional_encoding[:src.size(1), :]
        tgt_emb = self.embedding(tgt) + self.positional_encoding[:tgt.size(1), :]

        # Transformer
        output = self.transformer(
            src_emb.permute(1, 0, 2),  # 转换为 [seq_len, batch_size, embed_dim]
            tgt_emb.permute(1, 0, 2),  # 转换为 [seq_len, batch_size, embed_dim]
            src_mask=src_mask,
            tgt_mask=tgt_mask,
            src_key_padding_mask=src_padding_mask,
            tgt_key_padding_mask=tgt_padding_mask,
        )
        return self.fc_out(output.permute(1, 0, 2))  # 转回 [batch_size, seq_len, vocab_size]

# %%
# 模型参数
embed_dim = 64
num_heads = 8
num_layers = 4
max_len = 2048  # 填充后的最大序列长度
pad_token = V_dict["<PAD>"]
vocab_size = len(V_dict)
device = "cpu"
if torch.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"

# 初始化模型
model = MusicTransformer(vocab_size, embed_dim, num_heads, num_layers, max_len, pad_token).to(device)

# 忽略 PAD token 的损失
criterion = nn.CrossEntropyLoss(ignore_index=pad_token).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
from torch.utils.data import DataLoader

# 训练循环
num_epochs = 10
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch_inputs, batch_targets in tqdm.tqdm(dataloader, desc=f"[{epoch}]Training"):
        optimizer.zero_grad()

        batch_inputs = batch_inputs.to(device)
        batch_targets = batch_targets.to(device)

        # 准备目标序列
        tgt_input = batch_inputs
        tgt_output = batch_targets

        # 注意力掩码
        src_padding_mask = (batch_inputs == pad_token)  # 忽略输入的 PAD
        tgt_padding_mask = (tgt_input == pad_token)    # 忽略目标的 PAD
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt_input.size(1)).to(batch_inputs.device)

        # 前向传播
        outputs = model(batch_inputs, tgt_input, tgt_mask=tgt_mask, src_padding_mask=src_padding_mask, tgt_padding_mask=tgt_padding_mask)

        # 计算损失
        loss = criterion(outputs.view(-1, vocab_size), tgt_output.view(-1))
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {total_loss:.4f}")
# Out:
# [0]Training:   0%|          | 1/2639 [01:12<53:22:08, 72.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 25
#      22 tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt_input.size(1)).to(batch_inputs.device)
#      24 # 前向传播
# ---> 25 outputs = model(batch_inputs, tgt_input, tgt_mask=tgt_mask, src_padding_mask=src_padding_mask, tgt_padding_mask=tgt_padding_mask)
#      27 # 计算损失
#      28 loss = criterion(outputs.view(-1, vocab_size), tgt_output.view(-1))
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[84], line 25, in MusicTransformer.forward(self, src, tgt, src_mask, tgt_mask, src_padding_mask, tgt_padding_mask)
#      22 tgt_emb = self.embedding(tgt) + self.positional_encoding[:tgt.size(1), :]
#      24 # Transformer
# ---> 25 output = self.transformer(
#      26     src_emb.permute(1, 0, 2),  # 转换为 [seq_len, batch_size, embed_dim]
#      27     tgt_emb.permute(1, 0, 2),  # 转换为 [seq_len, batch_size, embed_dim]
#      28     src_mask=src_mask,
#      29     tgt_mask=tgt_mask,
#      30     src_key_padding_mask=src_padding_mask,
#      31     tgt_key_padding_mask=tgt_padding_mask,
#      32 )
#      33 return self.fc_out(output.permute(1, 0, 2))
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/transformer.py:272, in Transformer.forward(self, src, tgt, src_mask, tgt_mask, memory_mask, src_key_padding_mask, tgt_key_padding_mask, memory_key_padding_mask, src_is_causal, tgt_is_causal, memory_is_causal)
#     267 if src.size(-1) != self.d_model or tgt.size(-1) != self.d_model:
#     268     raise RuntimeError(
#     269         "the feature number of src and tgt must be equal to d_model"
#     270     )
# --> 272 memory = self.encoder(
#     273     src,
#     274     mask=src_mask,
#     275     src_key_padding_mask=src_key_padding_mask,
#     276     is_causal=src_is_causal,
#     277 )
#     278 output = self.decoder(
#     279     tgt,
#     280     memory,
#    (...)
#     286     memory_is_causal=memory_is_causal,
#     287 )
#     288 return output
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/transformer.py:511, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     508 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     510 for mod in self.layers:
# --> 511     output = mod(
#     512         output,
#     513         src_mask=mask,
#     514         is_causal=is_causal,
#     515         src_key_padding_mask=src_key_padding_mask_for_layers,
#     516     )
#     518 if convert_to_nested:
#     519     output = output.to_padded_tensor(0.0, src.size())
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/transformer.py:906, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     901 else:
#     902     x = self.norm1(
#     903         x
#     904         + self._sa_block(x, src_mask, src_key_padding_mask, is_causal=is_causal)
#     905     )
# --> 906     x = self.norm2(x + self._ff_block(x))
#     908 return x
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/transformer.py:932, in TransformerEncoderLayer._ff_block(self, x)
#     930 def _ff_block(self, x: Tensor) -> Tensor:
#     931     x = self.linear2(self.dropout(self.activation(self.linear1(x))))
# --> 932     return self.dropout2(x)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/modules/dropout.py:70, in Dropout.forward(self, input)
#      69 def forward(self, input: Tensor) -> Tensor:
# ---> 70     return F.dropout(input, self.p, self.training, self.inplace)
#
# File /opt/anaconda3/envs/retro/lib/python3.12/site-packages/torch/nn/functional.py:1425, in dropout(input, p, training, inplace)
#    1422 if p < 0.0 or p > 1.0:
#    1423     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1424 return (
# -> 1425     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1426 )
#
# KeyboardInterrupt:
